# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/prajwalsubedi/Desktop/Data science/Data Sets/credit.csv')

# %% [markdown]
# # How big is the data

# %%
df.shape
# Out:
# (10000, 10)

# %% [markdown]
# # How does the data look like?

# %%
df.head()  #give first 5 rows
# Out:
#    transaction_id  amount transaction_hour merchant_category  \
# 0               1   84.47               22       Electronics
# 1               2  541.82                3            Travel
# 2               3  237.01               17           Grocery
# 3               4  164.33                4           Grocery
# 4               5   30.53               15              Food
#
#    foreign_transaction  location_mismatch  device_trust_score  \
# 0                    0                  0                  66
# 1                    1                  0                  87
# 2                    0                  0                  49
# 3                    0                  1                  72
# 4                    0                  0                  79
#
#    velocity_last_24h  cardholder_age  is_fraud
# 0                  3            40.0       NaN
# 1                  1            64.0       0.0
# 2                  1            61.0       0.0
# ...

# %%
df.sample(5) # random rows from dataset
# Out:
#       transaction_id  amount transaction_hour merchant_category  \
# 926              927   56.32               14          Clothing
# 8555            8556  204.85               22       Electronics
# 756              757  174.20               18              Food
# 3429            3430  159.15               20       Electronics
# 1717            1718  213.76               21            Travel
#
#       foreign_transaction  location_mismatch  device_trust_score  \
# 926                     0                  0                  83
# 8555                    0                  0                  25
# 756                     1                  0                  43
# 3429                    0                  0                  86
# 1717                    0                  0                  49
#
#       velocity_last_24h  cardholder_age  is_fraud
# 926                   1            49.0       0.0
# 8555                  2            47.0       0.0
# ...

# %% [markdown]
# # What is data type of columns?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   transaction_id       10000 non-null  int64
#  1   amount               9999 non-null   float64
#  2   transaction_hour     10000 non-null  object
#  3   merchant_category    10000 non-null  object
#  4   foreign_transaction  10000 non-null  int64
#  5   location_mismatch    10000 non-null  int64
#  6   device_trust_score   10000 non-null  int64
#  7   velocity_last_24h    10000 non-null  int64
#  8   cardholder_age       9999 non-null   float64
#  9   is_fraud             9986 non-null   float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 781.4+ KB

# %% [markdown]
# # Are there are missing values?

# %%
df.isnull().sum()
# Out:
# transaction_id          0
# amount                  1
# transaction_hour        0
# merchant_category       0
# foreign_transaction     0
# location_mismatch       0
# device_trust_score      0
# velocity_last_24h       0
# cardholder_age          1
# is_fraud               14
# dtype: int64

# %% [markdown]
# # How does tha data look mathematically ?

# %%
df.describe()
# Out:
#        transaction_id       amount  foreign_transaction  location_mismatch  \
# count     10000.00000  9999.000000         10000.000000       10000.000000
# mean       5000.50000   175.948604             0.097900           0.139300
# std        2886.89568   175.402319             0.297194           2.002572
# min           1.00000     0.000000             0.000000           0.000000
# 25%        2500.75000    50.900000             0.000000           0.000000
# 50%        5000.50000   122.090000             0.000000           0.000000
# 75%        7500.25000   242.550000             0.000000           0.000000
# max       10000.00000  1471.040000             1.000000          97.000000
#
#        device_trust_score  velocity_last_24h  cardholder_age     is_fraud
# count        10000.000000       10000.000000     9999.000000  9986.000000
# mean            61.735500           2.053100       43.420242     0.015121
# ...

# %% [markdown]
# # Are there duplicate values ?

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # How is the correlation between cols?

# %%
df.corr(numeric_only=True)
# Out:
#                      transaction_id    amount  foreign_transaction  \
# transaction_id             1.000000 -0.017668            -0.004254
# amount                    -0.017668  1.000000             0.003827
# foreign_transaction       -0.004254  0.003827             1.000000
# location_mismatch         -0.038016 -0.001809             0.000609
# device_trust_score         0.016527  0.009992             0.012736
# velocity_last_24h         -0.042688 -0.004420            -0.005420
# cardholder_age             0.010117  0.013288             0.005469
# is_fraud                  -0.010431  0.028397             0.185683
#
#                      location_mismatch  device_trust_score  velocity_last_24h  \
# transaction_id               -0.038016            0.016527          -0.042688
# amount                       -0.001809            0.009992          -0.004420
# foreign_transaction           0.000609            0.012736          -0.005420
# ...
