# %%
import numpy as np 
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
import seaborn as sns

# %%
df = pd.read_csv('/Users/prajwalsubedi/Desktop/Data science/Data Sets/titanic.csv',usecols=['Age','Pclass','SibSp','Parch','Survived'])

# %%
df.head(5)
# Out:
#    Survived  Pclass   Age  SibSp  Parch
# 0         0       3  22.0      1      0
# 1         1       1  38.0      1      0
# 2         1       3  26.0      0      0
# 3         1       1  35.0      1      0
# 4         0       3  35.0      0      0

# %%
df.dropna(inplace=True)

# %%
x =df.iloc[:,1:5]
y= df.iloc[:,0]

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
x.head()
# Out:
#    Pclass   Age  SibSp  Parch
# 0       3  22.0      1      0
# 1       1  38.0      1      0
# 2       3  26.0      0      0
# 3       1  35.0      1      0
# 4       3  35.0      0      0

# %%
np.mean(cross_val_score(LogisticRegression(),x,y,scoring='accuracy',cv=20))
# Out:
# np.float64(0.6933333333333332)

# %%
x['Family_size']=x['SibSp']+x['Parch']+1

# %%
 x.head()
# Out:
#    Pclass   Age  SibSp  Parch  Family_size
# 0       3  22.0      1      0            2
# 1       1  38.0      1      0            2
# 2       3  26.0      0      0            1
# 3       1  35.0      1      0            2
# 4       3  35.0      0      0            1

# %%
def myfunc(num):
    if num ==1:
        return 0 #alone
    elif num>1 and num<=4: 
        return 1 #small family
    else:
        return 2 # large family

# %%
myfunc(4)
# Out:
# 1

# %%
x['Family_type']=x['Family_size'].apply(myfunc)

# %%
x.head()
# Out:
#    Pclass   Age  SibSp  Parch  Family_size  Family_type
# 0       3  22.0      1      0            2            1
# 1       1  38.0      1      0            2            1
# 2       3  26.0      0      0            1            0
# 3       1  35.0      1      0            2            1
# 4       3  35.0      0      0            1            0

# %%
x.drop(columns=['SibSp','Parch','Family_size'])
# Out:
#      Pclass   Age  Family_type
# 0         3  22.0            1
# 1         1  38.0            1
# 2         3  26.0            0
# 3         1  35.0            1
# 4         3  35.0            0
# ..      ...   ...          ...
# 885       3  39.0            2
# 886       2  27.0            0
# 887       1  19.0            0
# 889       1  26.0            0
# 890       3  32.0            0
#
# [714 rows x 3 columns]

# %%
np.mean(cross_val_score(LogisticRegression(),x,y,scoring='accuracy',cv=20))
# Out:
# np.float64(0.7031746031746031)
