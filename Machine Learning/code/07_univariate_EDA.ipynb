# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('/Users/prajwalsubedi/Desktop/Data science/Data Sets/credit.csv')

# %%
df.head()
# Out:
#    transaction_id  amount transaction_hour merchant_category  \
# 0               1   84.47               22       Electronics
# 1               2  541.82                3            Travel
# 2               3  237.01               17           Grocery
# 3               4  164.33                4           Grocery
# 4               5   30.53               15              Food
#
#    foreign_transaction  location_mismatch  device_trust_score  \
# 0                    0                  0                  66
# 1                    1                  0                  87
# 2                    0                  0                  49
# 3                    0                  1                  72
# 4                    0                  0                  79
#
#    velocity_last_24h  cardholder_age  is_fraud
# 0                  3            40.0       NaN
# 1                  1            64.0       0.0
# 2                  1            61.0       0.0
# ...

# %%
df.shape
# Out:
# (10000, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   transaction_id       10000 non-null  int64
#  1   amount               9999 non-null   float64
#  2   transaction_hour     10000 non-null  object
#  3   merchant_category    10000 non-null  object
#  4   foreign_transaction  10000 non-null  int64
#  5   location_mismatch    10000 non-null  int64
#  6   device_trust_score   10000 non-null  int64
#  7   velocity_last_24h    10000 non-null  int64
#  8   cardholder_age       9999 non-null   float64
#  9   is_fraud             9986 non-null   float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 781.4+ KB

# %% [markdown]
# # Knowing columns individually

# %% [markdown]
# # 1. Categorical Data

# %% [markdown]
# ## a. countplot

# %%
# sns.countplot(df['foreign_transaction'])
# df['foreign_transaction'].value_counts().plot(kind='bar')
df['is_fraud'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='is_fraud'>

# %% [markdown]
# ## b. Piechart

# %%
# df['is_fraud'].value_counts().plot(kind='pie',autopct='%.2f')
df['foreign_transaction'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # 2. Numerical

# %% [markdown]
# ## a. Histogram

# %%
plt.hist(df['amount'])
# Out:
# (array([5.688e+03, 2.412e+03, 1.065e+03, 4.760e+02, 2.090e+02, 8.700e+01,
#         3.500e+01, 1.500e+01, 7.000e+00, 5.000e+00]),
#  array([   0.   ,  147.104,  294.208,  441.312,  588.416,  735.52 ,
#          882.624, 1029.728, 1176.832, 1323.936, 1471.04 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## b. Distplot

# %%
sns.distplot(df['amount'])
# Out:
# /var/folders/nl/75k6nf4573d4dnj713sbnl5w0000gn/T/ipykernel_59200/1086040597.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['amount'])
# <Axes: xlabel='amount', ylabel='Density'>

# %%
df['amount'].skew()
# Out:
# np.float64(1.9191558398633963)

# %% [markdown]
# ## c. Boxplot

# %%
sns.boxplot(df['amount'])
# Out:
# <Axes: ylabel='amount'>
