# %%
import pickle 
import numpy as np

# %%
pipe = pickle.load(open('pipe.pkl','rb'))

# %%
# test_input2 = np.array([20,'male',102.2,'strong','Bangalore'],dtype=object).reshape(1,5)

# %%
# pipe.predict(test_input2)

# %%
import pandas as pd

test_input2 = pd.DataFrame(
    [[20, 'Female', 101, 'Mild', 'Dharan']],
    columns=['Age', 'Gender', 'Fever', 'Cough', 'City']  # EXACT same order
)

pipe.predict(test_input2)
# Out:
# array(['No'], dtype=object)
