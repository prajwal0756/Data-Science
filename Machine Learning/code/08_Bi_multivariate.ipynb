# %%
import pandas as pd
import seaborn as sns

# %%
# placement=pd.read_csv('/Users/prajwalsubedi/Desktop/Data science/Data Sets/placement.csv')
# churn=pd.read_csv('/Users/prajwalsubedi/Desktop/Data science/Data Sets/Telco_customer_churn.csv')
df= pd.read_csv('/Users/prajwalsubedi/Desktop/Data science/Data Sets/sample_store.csv',encoding='ISO-8859-1')
credit=pd.read_csv('/Users/prajwalsubedi/Desktop/Data science/Data Sets/credit.csv')

# %%
credit.head()
# Out:
#    transaction_id  amount transaction_hour merchant_category  \
# 0               1   84.47               22       Electronics
# 1               2  541.82                3            Travel
# 2               3  237.01               17           Grocery
# 3               4  164.33                4           Grocery
# 4               5   30.53               15              Food
#
#    foreign_transaction  location_mismatch  device_trust_score  \
# 0                    0                  0                  66
# 1                    1                  0                  87
# 2                    0                  0                  49
# 3                    0                  1                  72
# 4                    0                  0                  79
#
#    velocity_last_24h  cardholder_age  is_fraud
# 0                  3            40.0       NaN
# 1                  1            64.0       0.0
# 2                  1            61.0       0.0
# ...

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   transaction_id       10000 non-null  int64
#  1   amount               9999 non-null   float64
#  2   transaction_hour     10000 non-null  object
#  3   merchant_category    10000 non-null  object
#  4   foreign_transaction  10000 non-null  int64
#  5   location_mismatch    10000 non-null  int64
#  6   device_trust_score   10000 non-null  int64
#  7   velocity_last_24h    10000 non-null  int64
#  8   cardholder_age       9999 non-null   float64
#  9   is_fraud             9986 non-null   float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 781.4+ KB

# %% [markdown]
# # 1. Scatterplot(Num-Num)

# %%
sns.scatterplot(data=credit, x=credit['amount'],y=credit['transaction_id'])
# Out:
# <Axes: xlabel='amount', ylabel='transaction_id'>

# %%
sns.scatterplot(data=credit, x=credit['amount'],y=credit['transaction_id'], hue=credit['is_fraud'])
# Out:
# <Axes: xlabel='amount', ylabel='transaction_id'>

# %% [markdown]
# #### Another more coulumns can be added as
# #### sns.scatterplot(data=credit, x=credit['amount'],y=credit['transaction_id'], hue=credit['is_fraud'],style=df[''],col=[''])

# %% [markdown]
# # 2. Bar Plot(num-cate)

# %%
sns.barplot(x=credit['amount'],y=credit['merchant_category'],hue=credit['cardholder_age'])
# sns.barplot(x=df['Profit'],y=df['Category'],hue=df['Region'])
# Out:
# <Axes: xlabel='amount', ylabel='merchant_category'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# # 3. Box Plot(num-cate)

# %%
sns.boxplot(x=df['Profit'],y=df['Category'],hue=df['Sub-Category'])
# Out:
# <Axes: xlabel='Profit', ylabel='Category'>

# %% [markdown]
# # 4. Distplot(num-cate)

# %%
sns.distplot(credit[credit['foreign_transaction']==0]['amount'],hist=False)
sns.distplot(credit[credit['foreign_transaction']==1]['amount'],hist=False)
# Out:
# /var/folders/nl/75k6nf4573d4dnj713sbnl5w0000gn/T/ipykernel_87631/1499922454.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(credit[credit['foreign_transaction']==0]['amount'],hist=False)
# /var/folders/nl/75k6nf4573d4dnj713sbnl5w0000gn/T/ipykernel_87631/1499922454.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# # 5. HeatMap

# %%
sns.heatmap(pd.crosstab(df['Ship Mode'],df['Category']))
# Out:
# <Axes: xlabel='Category', ylabel='Ship Mode'>

# %%
df.groupby('Ship Mode').mean(numeric_only=True)['Sales'].plot(kind='bar')
# Out:
# <Axes: xlabel='Ship Mode'>

# %% [markdown]
# # 6. ClusterMap(cat-cat)

# %%
sns.clustermap(pd.crosstab(df['Category'],df['Sub-Category']))

# %% [markdown]
# # 7. Pairplot

# %%
sns.pairplot(df,hue='Category')

# %% [markdown]
# # 8. Lineplot(num-num)

# %%
new = df.groupby('Order Date').sum().reset_index()

# %%
sns.lineplot(x=new['Order Date'],y=new['Sales'])
# Out:
# <Axes: xlabel='Order Date', ylabel='Sales'>

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df['month'] = pd.to_datetime(df['Order Date']).dt.month
df['year'] = pd.to_datetime(df['Order Date']).dt.year

# %%
df.pivot_table(values='Sales',index='month',columns='year')
# Out:
# year         2014        2015        2016        2017
# month
# 1      180.213861  313.346131  208.342596  283.686284
# 2       98.258522  186.740797  276.853193  189.730219
# 3      354.719803  280.625014  317.275307  247.362827
# 4      209.595148  213.720053  227.941406  179.909045
# 5      193.838418  206.381414  253.278791  182.897150
# 6      256.260204  179.690522  202.736352  216.251942
# 7      237.387364  205.466607  195.333149  200.285027
# 8      182.414827  232.064982  176.791899  289.545358
# 9      305.139369  220.463884  202.231474  191.430614
# 10     197.820082  189.186286  304.529311  260.996387
# 11     247.260115  234.483221  214.626935  258.056264
# 12     250.164103  237.087092  275.565463  181.448742

# %%
sns.heatmap(df.pivot_table(values='Sales',index='month',columns='year'))
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(df.pivot_table(values='Sales',index='month',columns='year'))
