# %%
import pandas as pd
import requests

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/mcenter/v1/40381/hscard"

headers = {
    "x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com",
    "x-rapidapi-key": "00fbb7517emsh1620caca22a77bfp1d0ecdjsn194467302018"
}



response = requests.get(url, headers=headers)
data = response.json()

batsman_df = pd.json_normalize(data['scorecard'], record_path='batsman')
bowler_df = pd.json_normalize(data['scorecard'], record_path='bowler')


bowler_df
# Out:
#        id overs  maidens  wickets  runs economy            name  \
# 0   15475     4        0        2    29     7.2    Nisarg Patel
# 1    9748   3.5        0        3    33     8.6     Netravalkar
# 2   11450     3        0        0    34    11.3        Ali Khan
# 3   22901     4        0        2    32       8  Yasir Mohammad
# 4   22531     3        0        2    16     5.3  Vatsal Vaghela
# 5   22891     1        0        0     5       5   Ritwik Behera
# 6   10449     4        0        1    25     6.2      Mark Adair
# 7   10451     4        0        0    24       6  Barry McCarthy
# 8   18143     4        1        4    25     6.2  Curtis Campher
# 9   12769     4        0        0    31     7.8      Simi Singh
# 10  11124     3        0        1    27       9  Benjamin White
# 11   1114     1        0        0     4       4   Paul Stirling
#
#           nickname  iscaptain  iskeeper  ... dots balls   rpb  planid  \
# ...

# %%
batsman_df
# Out:
#        id  balls  runs  fours  sixes strkrate                 name  \
# 0    1114      5     5      1      0      100             Stirling
# 1    6710      5    10      2      0      200            Balbirnie
# 2   11131     56    84      9      3      150        Lorcan Tucker
# 3   18143     11    17      2      1   154.55       Curtis Campher
# 4    6471     10     5      0      0       50              Getkate
# 5   13309      5     4      0      0       80            Neil Rock
# 6   11129      3     1      0      0    33.33   William McClintock
# 7   10449      4     3      0      0       75           Mark Adair
# 8   12769     11    13      1      0   118.18           Simi Singh
# 9   10451      1     0      0      0        0       Barry McCarthy
# 10  11124      2     2      0      0      100       Benjamin White
# 11  22891     23    16      1      0    69.57        Ritwik Behera
# 12  22896     11    11      2      0      100           Ryan Scott
# ...

# %%
batsman_df = batsman_df[['name','runs','balls','fours','sixes','strkrate']]
bowler_df = bowler_df[['name','overs','maidens','runs','wickets','economy']]

# %%
batsman_df
# Out:
#                    name  runs  balls  fours  sixes strkrate
# 0              Stirling     5      5      1      0      100
# 1             Balbirnie    10      5      2      0      200
# 2         Lorcan Tucker    84     56      9      3      150
# 3        Curtis Campher    17     11      2      1   154.55
# 4               Getkate     5     10      0      0       50
# 5             Neil Rock     4      5      0      0       80
# 6    William McClintock     1      3      0      0    33.33
# 7            Mark Adair     3      4      0      0       75
# 8            Simi Singh    13     11      1      0   118.18
# 9        Barry McCarthy     0      1      0      0        0
# 10       Benjamin White     2      2      0      0      100
# 11        Ritwik Behera    16     23      1      0    69.57
# 12           Ryan Scott    11     11      2      0      100
# 13         Monank Patel    26     27      2      1     96.3
# 14       Gajanand Singh    22     20      1      1      110
# ...

# %%
bowler_df
# Out:
#               name overs  maidens  runs  wickets economy
# 0     Nisarg Patel     4        0    29        2     7.2
# 1      Netravalkar   3.5        0    33        3     8.6
# 2         Ali Khan     3        0    34        0    11.3
# 3   Yasir Mohammad     4        0    32        2       8
# 4   Vatsal Vaghela     3        0    16        2     5.3
# 5    Ritwik Behera     1        0     5        0       5
# 6       Mark Adair     4        0    25        1     6.2
# 7   Barry McCarthy     4        0    24        0       6
# 8   Curtis Campher     4        1    25        4     6.2
# 9       Simi Singh     4        0    31        0     7.8
# 10  Benjamin White     3        0    27        1       9
# 11   Paul Stirling     1        0     4        0       4
