# %%
import pandas as pd 
import numpy as np 
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder

# %%
df=pd.read_csv('/Users/prajwalsubedi/Desktop/Data science/Data Sets/covid_dataset.csv')

# %%
df.head()
# Out:
#    Age  Gender  Fever   Cough       City Has_Covid
# 0   56    Male  102.4    Mild     Mumbai        No
# 1   19  Female  101.6  Strong     Mumbai        No
# 2   76  Female  102.0    Mild    Kolkata        No
# 3   65    Male   99.7    Mild  Bangalore        No
# 4   25  Female  102.1    Mild      Delhi       Yes

# %%
df.isnull().sum()
# Out:
# Age          0
# Gender       0
# Fever        0
# Cough        0
# City         0
# Has_Covid    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df.drop['Has_Covid'],df['Has_Covid'],test_size=0.2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 x_train, x_test, y_train, y_test = train_test_split(df.drop['Has_Covid'],df['Has_Covid'],test_size=0.2)
#
# TypeError: 'method' object is not subscriptable
